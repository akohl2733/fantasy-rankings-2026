# %%
import pandas as pd

# %%
df = pd.read_parquet('./data/stats_player_reg_2025.parquet')
# df.columns.to_list()
# df['position_group'].unique()

# %%
df["fantasy_points_hppr"] = (df["fantasy_points"] + df["fantasy_points_ppr"]) / 2
df["hppr_points_per_game"] = df["fantasy_points_hppr"] / df["games"]

# %%
# wr data

# wr_df = df.query("position == 'WR' & games > 8")
wr_df = df.query("position == 'WR'")

wr_df["rank_ppg"] = wr_df['hppr_points_per_game'].rank(ascending=False, method='min')
wr_df["rank_total"] = wr_df['fantasy_points_hppr'].rank(ascending=False, method='min')
sorted_wr_df = wr_df.sort_values(by="rank_ppg")

wr1s = sorted_wr_df[["rank_ppg", "rank_total", "player_display_name", "games", "fantasy_points_hppr", "hppr_points_per_game"]]
wr1s.head(24)
# Out:
#       rank_ppg  rank_total player_display_name  games  fantasy_points_hppr  \
# 1413       1.0         1.0          Puka Nacua     16                310.5
# 1222       2.0         2.0  Jaxon Smith-Njigba     17                300.4
# 842        3.0         4.0       Ja'Marr Chase     16                251.1
# 877        4.0         3.0   Amon-Ra St. Brown     17                265.5
# 1407       5.0        41.0         Rashee Rice      8                123.6
# 974        6.0         5.0      George Pickens     17                245.4
# 966        7.0        17.0        Drake London     12                167.9
# 73         8.0         8.0       Davante Adams     14                192.9
# 967        9.0         6.0         Chris Olave     16                218.0
# 754       10.0         9.0        Nico Collins     15                190.7
# 696       11.0        20.0         CeeDee Lamb     13                163.4
# 720       12.0        12.0         Tee Higgins     15                182.1
# 552       13.0        14.0          A.J. Brown     15                181.3
# 1471      14.0        99.0        Malik Nabers      4                 48.1
# 1404      15.0         7.0         Zay Flowers     17                200.3
# 1089      16.0        62.0      Garrett Wilson      7                 81.5
# 1161      17.0        42.0    Christian Watson     10                114.9
# 1223      18.0        32.0    Quentin Johnston     13                145.7
# 968       19.0        10.0    Jameson Williams     17                187.4
# 156       20.0       109.0         Tyreek Hill      4                 43.0
# 321       21.0        11.0    Courtland Sutton     17                182.7
# 1155      22.0        16.0   Wan'Dale Robinson     16                171.9
# 1237      23.0        13.0      Michael Wilson     17                181.6
# 1083      24.0        24.0         Alec Pierce     15                159.8
#
#       hppr_points_per_game
# 1413             19.406250
# 1222             17.670588
# 842              15.693750
# 877              15.617647
# 1407             15.450000
# 974              14.435294
# 966              13.991667
# 73               13.778571
# 967              13.625000
# 754              12.713333
# 696              12.569231
# 720              12.140000
# 552              12.086667
# 1471             12.025000
# 1404             11.782353
# 1089             11.642857
# 1161             11.490000
# 1223             11.207692
# 968              11.023529
# 156              10.750000
# 321              10.747059
# 1155             10.743750
# 1237             10.682353
# 1083             10.653333

# %%
# rb data

# rb_df = df.query("position == 'RB' & games > 8")
rb_df = df.query("position == 'RB'")
rb_df["rank_ppg"] = rb_df['hppr_points_per_game'].rank(ascending=False, method='min')
rb_df["rank_total"] = rb_df['fantasy_points_hppr'].rank(ascending=False, method='min')
sorted_rb_df = rb_df.sort_values(by="rank_ppg")

rbs = sorted_rb_df[["rank_ppg", "rank_total", "player_display_name", "games", "fantasy_points_hppr", "hppr_points_per_game"]]
rbs.head(24)
# Out:
#       rank_ppg  rank_total  player_display_name  games  fantasy_points_hppr  \
# 182        1.0         1.0  Christian McCaffrey     17               365.60
# 634        2.0         2.0      Jonathan Taylor     17               339.30
# 1221       3.0         3.0       Bijan Robinson     17               331.30
# 1422       4.0         4.0         Jahmyr Gibbs     17               328.40
# 1391       5.0         5.0        De'Von Achane     16               289.30
# 975        6.0         6.0           James Cook     17               285.70
# 144        7.0         7.0        Derrick Henry     17               272.00
# 566        8.0        12.0          Josh Jacobs     15               219.10
# 1265       9.0         8.0          Chase Brown     17               248.10
# 1981      10.0        39.0         Cam Skattebo      8               115.70
# 1130      11.0         9.0       Kyren Williams     17               245.30
# 903       12.0        11.0     Javonte Williams     16               225.30
# 884       13.0        10.0       Travis Etienne     17               235.90
# 409       14.0        14.0       Saquon Barkley     16               213.80
# 1958      15.0        36.0      Omarion Hampton      9               119.70
# 653       16.0        15.0        D'Andre Swift     16               211.60
# 1750      17.0        13.0        Ashton Jeanty     17               217.60
# 1492      18.0        33.0         Bucky Irving     10               123.50
# 960       19.0        16.0        Jaylen Warren     16               197.10
# 1158      20.0        18.0          Breece Hall     16               189.66
# 829       21.0        25.0  Rhamondre Stevenson     14               162.80
# 610       22.0        17.0          Rico Dowdle     17               196.80
# 2018      23.0        26.0     Quinshon Judkins     14               156.80
# 1998      24.0        19.0   TreVeyon Henderson     17               188.70
#
#       hppr_points_per_game
# 182              21.505882
# 634              19.958824
# 1221             19.488235
# 1422             19.317647
# 1391             18.081250
# 975              16.805882
# 144              16.000000
# 566              14.606667
# 1265             14.594118
# 1981             14.462500
# 1130             14.429412
# 903              14.081250
# 884              13.876471
# 409              13.362500
# 1958             13.300000
# 653              13.225000
# 1750             12.800000
# 1492             12.350000
# 960              12.318750
# 1158             11.853750
# 829              11.628571
# 610              11.576471
# 2018             11.200000
# 1998             11.100000

# %%
# qb data

# qb_df = df.query("position == 'QB' & games > 8")
qb_df = df.query("position == 'QB'")
qb_df["rank_ppg"] = qb_df['hppr_points_per_game'].rank(ascending=False, method='min')
qb_df["rank_total"] = qb_df['fantasy_points_hppr'].rank(ascending=False, method='min')
sorted_qb_df = qb_df.sort_values(by="rank_ppg")

qbs = sorted_qb_df[["rank_ppg", "rank_total", "player_display_name", "games", "fantasy_points_hppr", "hppr_points_per_game"]]
qbs.head(24)
# Out:
#       rank_ppg  rank_total player_display_name  games  fantasy_points_hppr  \
# 414        1.0         1.0          Josh Allen     16               364.62
# 1654       2.0         2.0          Drake Maye     17               351.46
# 8          3.0         3.0    Matthew Stafford     17               350.38
# 244        4.0        11.0     Patrick Mahomes     14               285.18
# 882        5.0         4.0     Trevor Lawrence     17               338.18
# 1125       6.0        23.0         Brock Purdy      9               177.38
# 711        7.0         8.0         Jalen Hurts     16               301.06
# 1700       8.0         5.0      Caleb Williams     17               317.18
# 167        9.0         6.0        Dak Prescott     17               313.78
# 1588      10.0         7.0              Bo Nix     17               304.84
# 694       11.0        10.0      Justin Herbert     16               286.88
# 170       12.0         9.0          Jared Goff     17               297.06
# 571       13.0        18.0        Daniel Jones     13               226.44
# 1971      14.0        13.0         Jaxson Dart     14               241.58
# 737       15.0        29.0          Joe Burrow      8               134.46
# 390       16.0        20.0       Lamar Jackson     13               214.86
# 1693      17.0        34.0      Jayden Daniels      7               114.28
# 173       18.0        16.0     Jacoby Brissett     14               227.44
# 412       19.0        12.0      Baker Mayfield     17               271.92
# 867       20.0        28.0       Justin Fields      9               142.66
# 649       21.0        15.0         Jordan Love     15               235.14
# 464       22.0        38.0        Kyler Murray      5                77.78
# 1438      23.0        21.0         C.J. Stroud     14               208.54
# 2007      24.0        26.0        Tyler Shough     11               157.96
#
#       hppr_points_per_game
# 414              22.788750
# 1654             20.674118
# 8                20.610588
# 244              20.370000
# 882              19.892941
# 1125             19.708889
# 711              18.816250
# 1700             18.657647
# 167              18.457647
# 1588             17.931765
# 694              17.930000
# 170              17.474118
# 571              17.418462
# 1971             17.255714
# 737              16.807500
# 390              16.527692
# 1693             16.325714
# 173              16.245714
# 412              15.995294
# 867              15.851111
# 649              15.676000
# 464              15.556000
# 1438             14.895714
# 2007             14.360000

# %%
# te data

# te_df = df.query("position == 'TE' & games > 10")
te_df = df.query("position == 'TE'")
te_df["rank_ppg"] = te_df['hppr_points_per_game'].rank(ascending=False, method='min')
te_df["rank_total"] = te_df['fantasy_points_hppr'].rank(ascending=False, method='min')
sorted_te_df = te_df.sort_values(by="rank_ppg")

qbs = sorted_te_df[["rank_ppg", "rank_total", "player_display_name", "games", "fantasy_points_hppr", "hppr_points_per_game"]]
qbs.head(24)
# Out:
#       rank_ppg  rank_total player_display_name  games  fantasy_points_hppr  \
# 1093       1.0         1.0        Trey McBride     17                252.9
# 1374       2.0        21.0        Tucker Kraft      8                101.2
# 186        3.0        13.0       George Kittle     11                133.0
# 1472       4.0         9.0        Brock Bowers     12                144.2
# 323        5.0         4.0      Dallas Goedert     15                155.1
# 881        6.0         2.0          Kyle Pitts     17                166.8
# 1405       7.0        27.0         Sam LaPorta      9                 86.9
# 1957       8.0         6.0   Harold Fannin Jr.     16                150.4
# 49         9.0         3.0        Travis Kelce     17                155.2
# 1353      10.0        18.0      Dalton Kincaid     12                106.6
# 1756      11.0         5.0        Tyler Warren     17                150.5
# 168       12.0         7.0        Hunter Henry     17                148.8
# 1137      13.0         8.0       Jake Ferguson     17                147.1
# 89        14.0        30.0       Darren Waller      9                 76.7
# 1754      15.0        12.0    Colston Loveland     16                136.1
# 600       16.0        10.0       Juwan Johnson     17                141.4
# 337       17.0        11.0      Dalton Schultz     17                136.7
# 1355      18.0        23.0     Brenton Strange     12                 95.0
# 41        19.0        20.0           Zach Ertz     13                101.4
# 639       20.0        15.0     Colby Parkinson     14                108.3
# 937       21.0        31.0         Jake Tonges     10                 76.3
# 1621      22.0        14.0           AJ Barner     17                121.3
# 1810      23.0        17.0   Oronde Gadsden II     15                106.9
# 1651      24.0        19.0        Theo Johnson     15                105.3
#
#       hppr_points_per_game
# 1093             14.876471
# 1374             12.650000
# 186              12.090909
# 1472             12.016667
# 323              10.340000
# 881               9.811765
# 1405              9.655556
# 1957              9.400000
# 49                9.129412
# 1353              8.883333
# 1756              8.852941
# 168               8.752941
# 1137              8.652941
# 89                8.522222
# 1754              8.506250
# 600               8.317647
# 337               8.041176
# 1355              7.916667
# 41                7.800000
# 639               7.735714
# 937               7.630000
# 1621              7.135294
# 1810              7.126667
# 1651              7.020000
